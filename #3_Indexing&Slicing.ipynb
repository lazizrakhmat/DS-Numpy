# %% [markdown]
# <a href="https://colab.research.google.com/github/rakhmatAI/DataScience_numpy/blob/main/%233_Indexing%26Slicing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# Indeks va kesib olish asoslari
#
#
# ![index.png](data:image/png;base64,...)

# %%
arr = np.arange(10, 100, 10)
arr[-6]
# Out:
# 40

# %% [markdown]
# ![indexing.png](data:image/png;base64,...)
#
#
# #### Numpy kutubxonasida massivning kesib olingan qismga o'zgartirish kirtilinsa, asosiy manba massivga ta'sir qiladi.

# %%
arr
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90])

# %%
arr[3:5] # 3 dan 5 gacha bo'lgan elementlarni kesib olib qaytaradi, 5 ni o'zi kirmaydi
# Out:
# array([40, 50])

# %%
sliced_arr = arr[3:5]
sliced_arr[:] = 1 ,2
sliced_arr
# Out:
# array([1, 2])

# %%
arr
# Out:
# array([10, 20, 30,  1,  2, 60, 70, 80, 90])

# %% [markdown]
# ```copy``` metodi

# %%
arr1 = np.arange(10, 100, 10)
arr1
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90])

# %%
sliced_arr1 = arr1[4:6].copy()
sliced_arr1[:] = 0
sliced_arr1
# Out:
# array([0, 0])

# %%
arr1
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90])
